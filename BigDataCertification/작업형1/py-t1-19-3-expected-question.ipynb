# %% [markdown]
# ### 주어진 데이터에서 2022년 월별 Sales 합계 중 가장 큰 금액과
# ### 2023년 월별 Sales 합계 중 가장 큰 금액의 차이를 절대값으로 구하시오.
# ### 단 Events컬럼이 '1'인경우 80%의 Salse값만 반영함
# ### (최종값은 소수점 반올림 후 정수 출력)
# - 데이터셋 : basic2.csv
# - 오른쪽 상단 copy&edit 클릭 -> 예상문제 풀이 시작

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
# 데이터 불러오기 (datatime컬럼 지정)
df = pd.read_csv("../input/bigdatacertificationkr/basic2.csv", 
                 parse_dates=['Date'])

# %%
df_2 = pd.read_csv("../input/bigdatacertificationkr/basic2.csv")

# %%
df.head()
# Out:
#         Date     Sales      PV      UV  Events
# 0 2022-01-01  22711525  397349  4421.0       1
# 1 2022-01-02     36779    3969  2289.0       0
# 2 2022-01-03  13943875  373890     NaN       1
# 3 2022-01-04   8088593  142054  2157.0       0
# 4 2022-01-05   2395374  190684     NaN       0

# %%
df_2.head()
# Out:
#          Date     Sales      PV      UV  Events
# 0  2022-01-01  22711525  397349  4421.0       1
# 1  2022-01-02     36779    3969  2289.0       0
# 2  2022-01-03  13943875  373890     NaN       1
# 3  2022-01-04   8088593  142054  2157.0       0
# 4  2022-01-05   2395374  190684     NaN       0

# %%
print(df.info(), df_2.info()) # parse_dates 로 지정하면 datetime 형식으로 지정되어 있는 것을 볼 수 있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    730 non-null    datetime64[ns]
#  1   Sales   730 non-null    int64
#  2   PV      730 non-null    int64
#  3   UV      684 non-null    float64
#  4   Events  730 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 28.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    730 non-null    object
#  1   Sales   730 non-null    int64
#  2   PV      730 non-null    int64
#  3   UV      684 non-null    float64
#  4   Events  730 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 28.6+ KB
# None None

# %%
# 날짜 컬럼 생성
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day
df['dayofweek'] = df['Date'].dt.dayofweek

# %%
# 이벤트가 1인 sales값은 80%만 반영

def event_sales(x):
    if x['Events'] == 1:
        x['Sales2'] = x['Sales']*0.8
    else:
        x['Sales2'] = x['Sales']
    return x


df = df.apply(lambda x: event_sales(x), axis=1) #1일 경우 row, 0일 경우 컬럼
df.head()
# Out:
#         Date     Sales      PV      UV  Events  year  month  day  dayofweek  \
# 0 2022-01-01  22711525  397349  4421.0       1  2022      1    1          5
# 1 2022-01-02     36779    3969  2289.0       0  2022      1    2          6
# 2 2022-01-03  13943875  373890     NaN       1  2022      1    3          0
# 3 2022-01-04   8088593  142054  2157.0       0  2022      1    4          1
# 4 2022-01-05   2395374  190684     NaN       0  2022      1    5          2
#
#        Sales2
# 0  18169220.0
# 1     36779.0
# 2  11155100.0
# 3   8088593.0
# 4   2395374.0

# %%
# 2022년 월별 합계 중 가장 큰 값
cond = df['year'] == 2022
df1 = df[cond]
sale1 = df1.groupby('month')['Sales2'].sum().max()
sale1
# Out:
# 197145878.0

# %%
df1.groupby('month')['Sales2'].sum()  # 왜 sum 을 하나요? 그냥 groupby 만 시켜놓으면 안 보이거든요.
# Out:
# month
# 1     114475247.2
# 2     153453688.6
# 3     172483809.4
# 4     111466880.8
# 5     121801396.0
# 6     165288258.4
# 7     197145878.0
# 8     108173602.2
# 9     157752502.6
# 10    183253174.0
# 11     89359502.2
# 12    191208107.8
# Name: Sales2, dtype: float64

# %%
# 2023년 월별 합계 중 가장 큰 값
cond = df['year'] == 2023
df2 = df[cond]
sale2 = df2.groupby('month')['Sales2'].sum().max()
sale2

# %%
# 결과값 반올림 후 정수 출력
int(round(abs(sale1 - sale2),0))
