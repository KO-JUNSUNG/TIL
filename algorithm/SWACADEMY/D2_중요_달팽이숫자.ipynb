# %% [markdown]
# 달팽이는 1부터 N*N까지의 숫자가 시계방향으로 이루어져 있다.
#
# 다음과 같이 정수 N을 입력 받아 N크기의 달팽이를 출력하시오.
#
#
# [예제]
#
# N이 3일 경우,
#
#
#
#
# N이 4일 경우,
#
#
#
# [제약사항]
#
# 달팽이의 크기 N은 1 이상 10 이하의 정수이다. (1 ≤ N ≤ 10)
#
#
# [입력]
#
# 가장 첫 줄에는 테스트 케이스의 개수 T가 주어지고, 그 아래로 각 테스트 케이스가 주어진다.
#
# 각 테스트 케이스에는 N이 주어진다.
#
# ```python
#
# # 입력
# 2
# 3
# 4
#
#
# ```
#
#
# [출력]
#
# 각 줄은 '#t'로 시작하고, 다음 줄부터 빈칸을 사이에 두고 달팽이 숫자를 출력한다.
#
# (t는 테스트 케이스의 번호를 의미하며 1부터 시작한다.)
#
#
# ```python
# #1
# 1 2 3
# 8 9 4
# 7 6 5
# #2
# 1 2 3 4
# 12 13 14 5
# 11 16 15 6
# 10 9 8 7
# ```

# %%
T = int(input())
# 여러개의 테스트 케이스가 주어지므로, 각각을 처리합니다.
for test_case in range(1, T + 1):
    n = int(input())
    dist = [[0, 1], [1, 0], [0, -1], [-1, 0]] # 우, 하, 좌, 상
    snail = [[0] * n for _ in range(n)] # 0으로 채워진 n*n 빈달팽이 생성
    num = 1 # 달팽이를 채울 숫자
    d = 0 # 달팽이 이동방향. 기본 우측으로 이동하므로, d=0 (열을 바꾸지 않음)
    x, y = 0, -1 # 시작위치
    while num <= (n*n):
        nx, ny = x + dist[d][0], y + dist[d][1]  # [][1] -> 열이 한 칸씩 오른쪽으로 이동. nx, ny 는 이동한 위치.
        if 0 <= nx < n and  0<= ny < n and snail[nx][ny] == 0 :
            snail[nx][ny] = num # 숫자 넣어주기
            num += 1 # 숫자 증가
            x, y = nx, ny # 현재 위치 갱신
             
        # 달팽이 크기에서 벗어났거나, 해당 위치에 이미 숫자가 부여되어 있는 경우
        # k값 조정을 통해 방향을 바꾼다.
        else:
            d = (d+1) % 4 # 0, 1, 2, 3 으로만 움직일 수 있게 나머지를 구함
    print(f"#{test_case}")
    for row in snail:
        print(*row)

# %% [markdown]
# 1. T = int(input()): 테스트 케이스의 개수를 입력받습니다.
#
# 2. for test_case in range(1, T + 1):: 테스트 케이스의 개수만큼 반복합니다.
#
# 3. n = int(input()): 달팽이의 크기 N을 입력받습니다.
#
# 4. dist = [[0, 1], [1, 0], [0, -1], [-1, 0]]: 방향 벡터를 정의합니다. 우(오른쪽), 하(아래쪽), 좌(왼쪽), 상(위쪽) 순서로 이동합니다.
#
# 5. snail = [[0] * n for _ in range(n)]: N x N 크기의 2차원 리스트를 생성하고 0으로 초기화합니다. 이 리스트는 달팽이 모양으로 숫자를 채워나갈 공간입니다.
#
# 6. num = 1: 달팽이에 채울 숫자를 1로 초기화합니다.
#
# 7. d = 0: 달팽이의 이동 방향을 나타내는 변수입니다. 초기 값은 오른쪽(우)입니다.
#
# 8. x, y = 0, -1: 시작 위치를 설정합니다. 시작 위치는 좌측 상단이므로 (0, -1)로 설정합니다.
#
# 9. while num <= (n*n):: num이 N x N보다 작거나 같은 동안 반복합니다.
#
# 10. nx, ny = x + dist[d][0], y + dist[d][1]: 현재 위치에서 이동 방향으로 한 칸 이동한 위치를 계산합니다.
#
# 11. if 0 <= nx < n and 0<= ny < n and snail[nx][ny] == 0:: 계산한 위치가 달팽이의 범위 내에 있고, 아직 숫자가 채워지지 않은 경우에만 실행합니다.
#
# 12. snail[nx][ny] = num: 해당 위치에 num 값을 채웁니다.
#
# 13. num += 1: num 값을 1 증가시킵니다.
#
# 14. x, y = nx, ny: 현재 위치를 업데이트합니다.
#
# 15. else: d = (d+1) % 4: 범위를 벗어나거나 이미 숫자가 채워진 경우 방향을 변경합니다. 오른쪽(우), 아래쪽(하), 왼쪽(좌), 위쪽(상) 순서로 방향을 변경합니다.
#
# 16. print(f"#{test_case}"): 테스트 케이스 번호를 출력합니다.
#
# 17. for row in snail: print(*row): 달팽이 리스트를 한 줄씩 출력합니다. *row를 통해 리스트를 언패킹하여 공백으로 구분된 형태로 출력합니다.
#
# - 이렇게 코드는 달팽이 숫자를 생성하고 출력하는 과정을 수행합니다.
