# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# N,M = map(int,input().split())
# S = list(input())

# from collections import deque

# origin = deque(S)
# queue = deque()

# # 큐에 들어온 마지막 n번째 원소가 동일할 경우 -> 삭제함
# for i in range(N):
# 	if len(queue) >= M:
# 		queue.append(origin.popleft())
# 		if queue[-M:]
# 	else:
# 		queue.append(origin.popleft())

import sys
input = sys.stdin.readline

N, M = map(int, input().split())
S = input().rstrip()
Q = []
Q.append(('', 1))

S += 'z'
for c in S:
    if Q[-1][0] != c:
        if M <= Q[-1][1]:
            top = Q[-1][0]
            while top == Q[-1][0]:
                Q.pop()
    if Q[-1][0] == c:
        Q.append((c, Q[-1][1] + 1))
    else:
        Q.append((c, 1))
Q.pop()

if len(Q) > 1:
    for c, n in Q:
        print(c, end='')
else:
    print("CLEAR!")
