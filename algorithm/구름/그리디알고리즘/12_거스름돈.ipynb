# %% [markdown]
# ![image.png](attachment:image.png)

# %%
coin = [40, 20, 10, 5, 1]
N = int(input())
count = 0
for i in coin:
    count += N // i
    N %= i
print(count)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
