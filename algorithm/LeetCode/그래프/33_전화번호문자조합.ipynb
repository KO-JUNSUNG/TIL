# %% [markdown]
# # 2에서 9까지 숫자가 주어졌을 때 전화번호로 조합 가능한 모든 문자를 출력하라.
#
# - 입력
# ```python
# "23"
# ```
# - 출력
# ```python
# ["ad","ae","af","bd","be","bf","cd","ce","cf]
# ```
#
# - 설명
#     - 2는 abc, 3은 def 가 가능하므로 각각 한 문자씩 9개의 문자로 조합 가능하다.
#
# 1. 옛날 핸드폰 문자 입력방식을 생각하면 된다.
#     - 2 = a,b,c
#     - 3 = d,e,f
#     - 4 = g,h,i
#     - 5 = j,k,l
#     - 6 = m,n,o
#     - 7 = p,q,r,s
#     - 8 = t,u,v
#     - 9 = w,x,y,z

# %% [markdown]
# ## 팁: DFS 는 보통 재귀로 구현한다. DFS 는 가지치기와 백트래킹이 가미된 브루트포스 방식이다.

# %%
from typing import List
# 풀이 1. 모든 조합 탐색.
def letterCombinations(digits:str)->List[str]:
    
    def dfs(index, path):
        # 끝까지 탐색하면 백트래킹
        # 백트래킹 = (해결책에 대한 후보를 구축해 나아가다 가능성이 없다고 판단되는 즉시 후보를 포기(백트랙)하고 정답을 찾아가는 범용적 알고리즘)
        if len(path) == len(digits):
            result.append(path)
            return
        # 입력값 자릿수 단위 반복
        for i in range(index, len(digits)):
            # 숫자에 해당하는 모든 문자열 반복
            for j in dic[digits[i]]:
                dfs(i+1, path + j)
    
    # 예외처리
    if not digits:
        return []
    
    dic = {"2": "abc", "3": "def", "4": "ghi", "5": "jkl", "6": "mno", "7":"pqrs", "8": "tuv", "9":"wxyz"}
    result = []
    dfs(0, "")

    return result

# %%
letterCombinations("23")
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %% [markdown]
# - 이 문제는 전체를 탐색하여 풀이할 수 있다. 항상 전체를 탐색해야 하고, 가지치기 등으로 최적화할 수 있는 문제는 아니기 때문에 어떻게 풀이하든 결과는 비슷하다.
# - 가능한 경우의 수를 모두 조합하는 형태로 전체를 탐색한 후 백트래킹하면서 결과를 조합할 수 있다.
#
# ![image.png](attachment:image.png)
#
# - 이 그림에서 digits 는 입력값이며 각 자릿수에 해당하는 키판 배열을 DFS 로 탐색하면 결과가 완성된다.
# - 마찬가지로 digits 는 입력값이며 dic은 키판배열이다. 입력값을 자릿수로 쪼개어 반복하고 숫자에 해당하는 모든 문자열을 반복하면서 마찬가지로 문자 단위로 재귀탐색한다.
